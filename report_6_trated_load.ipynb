# %%
import numpy as np

import analyze_control as ac

# %%
CASE = 6
d_case6 = ac.get_main_value(6)

# %% [markdown]
# # 最大暖房出力

# %%
data = [
    (d_case6['time_value']['maximum_output_heating_room1_MJ/h'], 'room 1'),
    (d_case6['time_value']['maximum_output_heating_room2_MJ/h'], 'room 2'),
    (d_case6['time_value']['maximum_output_heating_room3_MJ/h'], 'room 3'),
    (d_case6['time_value']['maximum_output_heating_room4_MJ/h'], 'room 4'),
    (d_case6['time_value']['maximum_output_heating_room5_MJ/h'], 'room 5'),
]

ac.draw_graph('maximum output, MJ/d', data, op='itg')

# %% [markdown]
# # 最大冷房顕熱出力

# %%
data = [
    (d_case6['time_value']['maximum_output_sensible_cooling_room1_MJ/h'], 'room 1 sensible'),
    (d_case6['time_value']['maximum_output_sensible_cooling_room2_MJ/h'], 'room 2 sensible'),
    (d_case6['time_value']['maximum_output_sensible_cooling_room3_MJ/h'], 'room 3 sensible'),
    (d_case6['time_value']['maximum_output_sensible_cooling_room4_MJ/h'], 'room 4 sensible'),
    (d_case6['time_value']['maximum_output_sensible_cooling_room5_MJ/h'], 'room 5 sensible'),
]

ac.draw_graph('maximum output, MJ/d', data, op='itg')

# %% [markdown]
# # 最大冷房潜熱出力

# %%
data = [
    (d_case6['time_value']['maximum_output_latent_cooling_room1_MJ/h'], 'room 1 latent'),
    (d_case6['time_value']['maximum_output_latent_cooling_room2_MJ/h'], 'room 2 latent'),
    (d_case6['time_value']['maximum_output_latent_cooling_room3_MJ/h'], 'room 3 latent'),
    (d_case6['time_value']['maximum_output_latent_cooling_room4_MJ/h'], 'room 4 latent'),
    (d_case6['time_value']['maximum_output_latent_cooling_room5_MJ/h'], 'room 5 latent'),
]

ac.draw_graph('maximum output, MJ/d', data, op='itg')

# %% [markdown]
# # 最大出力・処理負荷・未処理負荷

# %% [markdown]
# ## 暖房

# %% [markdown]
# ### Room 1

# %%
data = [
    (d_case6['time_value']['maximum_output_heating_room1_MJ/h'], 'maximum output'),
    (d_case6['time_value']['treated_heating_load_room1_MJ/h'], 'treated load'),
    (d_case6['time_value']['untreated_heating_load_room1_MJ/h'], 'untreated load'),
]

ac.draw_graph('maximum output, load, MJ/d', data, op='itg')

# %% [markdown]
# ### Room 2

# %%
data = [
    (d_case6['time_value']['maximum_output_heating_room2_MJ/h'], 'maximum output'),
    (d_case6['time_value']['treated_heating_load_room2_MJ/h'], 'treated load'),
    (d_case6['time_value']['untreated_heating_load_room2_MJ/h'], 'untreated load'),
]

ac.draw_graph('maximum output, load, MJ/d', data, op='itg')

# %% [markdown]
# ### Room 3

# %%
data = [
    (d_case6['time_value']['maximum_output_heating_room3_MJ/h'], 'maximum output'),
    (d_case6['time_value']['treated_heating_load_room3_MJ/h'], 'treated load'),
    (d_case6['time_value']['untreated_heating_load_room3_MJ/h'], 'untreated load'),
]

ac.draw_graph('maximum output, load, MJ/d', data, op='itg')

# %% [markdown]
# ### Room 4

# %%
data = [
    (d_case6['time_value']['maximum_output_heating_room4_MJ/h'], 'maximum output'),
    (d_case6['time_value']['treated_heating_load_room4_MJ/h'], 'treated load'),
    (d_case6['time_value']['untreated_heating_load_room4_MJ/h'], 'untreated load'),
]

ac.draw_graph('maximum output, load, MJ/d', data, op='itg')

# %% [markdown]
# ### Room 5

# %%
data = [
    (d_case6['time_value']['maximum_output_heating_room5_MJ/h'], 'maximum output'),
    (d_case6['time_value']['treated_heating_load_room5_MJ/h'], 'treated load'),
    (d_case6['time_value']['untreated_heating_load_room5_MJ/h'], 'untreated load'),
]

ac.draw_graph('maximum output, load, MJ/d', data, op='itg')

# %% [markdown]
# ## 冷房

# %% [markdown]
# ### Room 1

# %%
data = [
    (d_case6['time_value']['maximum_output_sensible_cooling_room1_MJ/h'], 'maximum output sensible'),
    (d_case6['time_value']['maximum_output_latent_cooling_room1_MJ/h'], 'maximum output latent'),
    (d_case6['time_value']['treated_sensible_cooling_load_room1_MJ/h'], 'treated load sensible'),
    (d_case6['time_value']['treated_latent_cooling_load_room1_MJ/h'], 'treated load latent'),
    (d_case6['time_value']['untreated_sensible_cooling_load_room1_MJ/h'], 'untreated load sensible'),
    (d_case6['time_value']['untreated_latent_cooling_load_room1_MJ/h'], 'untreated load latent'),
]

ac.draw_graph('maximum output, load, MJ/d', data, op='itg')

# %% [markdown]
# ### Room 2

# %%
data = [
    (d_case6['time_value']['maximum_output_sensible_cooling_room2_MJ/h'], 'maximum output sensible'),
    (d_case6['time_value']['maximum_output_latent_cooling_room2_MJ/h'], 'maximum output latent'),
    (d_case6['time_value']['treated_sensible_cooling_load_room2_MJ/h'], 'treated load sensible'),
    (d_case6['time_value']['treated_latent_cooling_load_room2_MJ/h'], 'treated load latent'),
    (d_case6['time_value']['untreated_sensible_cooling_load_room2_MJ/h'], 'untreated load sensible'),
    (d_case6['time_value']['untreated_latent_cooling_load_room2_MJ/h'], 'untreated load latent'),
]

ac.draw_graph('maximum output, load, MJ/d', data, op='itg')

# %% [markdown]
# ### Room 3

# %%
data = [
    (d_case6['time_value']['maximum_output_sensible_cooling_room3_MJ/h'], 'maximum output sensible'),
    (d_case6['time_value']['maximum_output_latent_cooling_room3_MJ/h'], 'maximum output latent'),
    (d_case6['time_value']['treated_sensible_cooling_load_room3_MJ/h'], 'treated load sensible'),
    (d_case6['time_value']['treated_latent_cooling_load_room3_MJ/h'], 'treated load latent'),
    (d_case6['time_value']['untreated_sensible_cooling_load_room3_MJ/h'], 'untreated load sensible'),
    (d_case6['time_value']['untreated_latent_cooling_load_room3_MJ/h'], 'untreated load latent'),
]

ac.draw_graph('maximum output, load, MJ/d', data, op='itg')

# %% [markdown]
# ### Room 4

# %%
data = [
    (d_case6['time_value']['maximum_output_sensible_cooling_room4_MJ/h'], 'maximum output sensible'),
    (d_case6['time_value']['maximum_output_latent_cooling_room4_MJ/h'], 'maximum output latent'),
    (d_case6['time_value']['treated_sensible_cooling_load_room4_MJ/h'], 'treated load sensible'),
    (d_case6['time_value']['treated_latent_cooling_load_room4_MJ/h'], 'treated load latent'),
    (d_case6['time_value']['untreated_sensible_cooling_load_room4_MJ/h'], 'untreated load sensible'),
    (d_case6['time_value']['untreated_latent_cooling_load_room4_MJ/h'], 'untreated load latent'),
]

ac.draw_graph('maximum output, load, MJ/d', data, op='itg')

# %% [markdown]
# ### Room 5

# %%
data = [
    (d_case6['time_value']['maximum_output_sensible_cooling_room5_MJ/h'], 'maximum output sensible'),
    (d_case6['time_value']['maximum_output_latent_cooling_room5_MJ/h'], 'maximum output latent'),
    (d_case6['time_value']['treated_sensible_cooling_load_room5_MJ/h'], 'treated load sensible'),
    (d_case6['time_value']['treated_latent_cooling_load_room5_MJ/h'], 'treated load latent'),
    (d_case6['time_value']['untreated_sensible_cooling_load_room5_MJ/h'], 'untreated load sensible'),
    (d_case6['time_value']['untreated_latent_cooling_load_room5_MJ/h'], 'untreated load latent'),
]

ac.draw_graph('maximum output, load, MJ/d', data, op='itg')
