# %%
import analyze_control as ac

# %% [markdown]
# # 外気温度（最大・平均・最小）

# %%
v = ac.get_outdoor_temperature(1)
ac.draw_graph('temperature, degree C', [(v,'region1')], op='a3')

# %%
v = ac.get_outdoor_temperature(2)
ac.draw_graph('temperature, degree C', [(v,'region2')], op='a3')

# %%
v = ac.get_outdoor_temperature(3)
ac.draw_graph('temperature, degree C', [(v,'region3')], op='a3')

# %%
v = ac.get_outdoor_temperature(4)
ac.draw_graph('temperature, degree C', [(v,'region4')], op='a3')

# %%
v = ac.get_outdoor_temperature(5)
ac.draw_graph('temperature, degree C', [(v,'region5')], op='a3')

# %%
v = ac.get_outdoor_temperature(6)
ac.draw_graph('temperature, degree C', [(v,'region6')], op='a3')

# %%
v = ac.get_outdoor_temperature(7)
ac.draw_graph('temperature, degree C', [(v,'region7')], op='a3')

# %%
v = ac.get_outdoor_temperature(8)
ac.draw_graph('temperature, degree C', [(v,'region8')], op='a3')

# %% [markdown]
# # 外気温度（平均・各地域）

# %%
data = [
    (ac.get_outdoor_temperature(1), 'region1'),
    (ac.get_outdoor_temperature(2), 'region2'),
    (ac.get_outdoor_temperature(3), 'region3'),
    (ac.get_outdoor_temperature(4), 'region4'),
    (ac.get_outdoor_temperature(5), 'region5'),
    (ac.get_outdoor_temperature(6), 'region6'),
    (ac.get_outdoor_temperature(7), 'region7'),
    (ac.get_outdoor_temperature(8), 'region8')
]
ac.draw_graph('daily average temperature, degree C',data, op='ave')

# %% [markdown]
# # 絶対湿度（平均・各地域）

# %%
data = [
    (ac.get_outdoor_absolute_humidity(1), 'region1'),
    (ac.get_outdoor_absolute_humidity(2), 'region2'),
    (ac.get_outdoor_absolute_humidity(3), 'region3'),
    (ac.get_outdoor_absolute_humidity(4), 'region4'),
    (ac.get_outdoor_absolute_humidity(5), 'region5'),
    (ac.get_outdoor_absolute_humidity(6), 'region6'),
    (ac.get_outdoor_absolute_humidity(7), 'region7'),
    (ac.get_outdoor_absolute_humidity(8), 'region8')
]
ac.draw_graph('daily average absolute humidity, kg/kgDA',data, op='ave')

# %% [markdown]
# # 法線面直達日射量

# %% [markdown]
# 日変動が激しすぎるので、地域別に表示

# %% [markdown]
# #### 1 地域

# %%
data = [(ac.get_direct_solar(1)*3600*10**(-6), 'region1')]
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# #### 2 地域

# %%
data = [(ac.get_direct_solar(2)*3600*10**(-6), 'region2')]
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# #### 3 地域

# %%
data = [(ac.get_direct_solar(3)*3600*10**(-6), 'region3')]
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# #### 4 地域

# %%
data = [(ac.get_direct_solar(4)*3600*10**(-6), 'region4')]
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# #### 5 地域

# %%
data = [(ac.get_direct_solar(5)*3600*10**(-6), 'region5')]
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# #### 6 地域

# %%
data = [(ac.get_direct_solar(6)*3600*10**(-6), 'region6')]
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# #### 7 地域

# %%
data = [(ac.get_direct_solar(7)*3600*10**(-6), 'region7')]
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# #### 8 地域

# %%
data = [(ac.get_direct_solar(8)*3600*10**(-6), 'region8')]
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# # 水平面天空日射量

# %%
data = [
    (ac.get_horizontal_sky_solar(1)*3600*10**(-6), 'region1'),
    (ac.get_horizontal_sky_solar(2)*3600*10**(-6), 'region2'),
    (ac.get_horizontal_sky_solar(3)*3600*10**(-6), 'region3'),
    (ac.get_horizontal_sky_solar(4)*3600*10**(-6), 'region4'),
    (ac.get_horizontal_sky_solar(5)*3600*10**(-6), 'region5'),
    (ac.get_horizontal_sky_solar(6)*3600*10**(-6), 'region6'),
    (ac.get_horizontal_sky_solar(7)*3600*10**(-6), 'region7'),
    (ac.get_horizontal_sky_solar(8)*3600*10**(-6), 'region8')
]
ac.draw_graph('daily integrated sky solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# # 水平面夜間放射量

# %%
data = [
    (ac.get_night_radiation(1)*3600*10**(-6), 'region1'),
    (ac.get_night_radiation(2)*3600*10**(-6), 'region2'),
    (ac.get_night_radiation(3)*3600*10**(-6), 'region3'),
    (ac.get_night_radiation(4)*3600*10**(-6), 'region4'),
    (ac.get_night_radiation(5)*3600*10**(-6), 'region5'),
    (ac.get_night_radiation(6)*3600*10**(-6), 'region6'),
    (ac.get_night_radiation(7)*3600*10**(-6), 'region7'),
    (ac.get_night_radiation(8)*3600*10**(-6), 'region8')
]
ac.draw_graph('daily integrated night solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# # 水平面日射量

# %%
data = [
    (ac.get_horizontal_solar(1)*3600*10**(-6), 'region1'),
    (ac.get_horizontal_solar(2)*3600*10**(-6), 'region2'),
    (ac.get_horizontal_solar(3)*3600*10**(-6), 'region3'),
    (ac.get_horizontal_solar(4)*3600*10**(-6), 'region4'),
    (ac.get_horizontal_solar(5)*3600*10**(-6), 'region5'),
    (ac.get_horizontal_solar(6)*3600*10**(-6), 'region6'),
    (ac.get_horizontal_solar(7)*3600*10**(-6), 'region7'),
    (ac.get_horizontal_solar(8)*3600*10**(-6), 'region8')
]
ac.draw_graph('daily integrated night solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# # 相当外気温度

# %%
data = [
    (ac.get_sat_temperature(1)*3600*10**(-6), 'region1'),
    (ac.get_sat_temperature(2)*3600*10**(-6), 'region2'),
    (ac.get_sat_temperature(3)*3600*10**(-6), 'region3'),
    (ac.get_sat_temperature(4)*3600*10**(-6), 'region4'),
    (ac.get_sat_temperature(5)*3600*10**(-6), 'region5'),
    (ac.get_sat_temperature(6)*3600*10**(-6), 'region6'),
    (ac.get_sat_temperature(7)*3600*10**(-6), 'region7'),
    (ac.get_sat_temperature(8)*3600*10**(-6), 'region8')
]
ac.draw_graph('daily average SAT temperature, degree C',data, op='ave')
