# %%
import read_conditions as rc
import analyze_control as ac

# %% [markdown]
# # 外気温度（最大・平均・最小）

# %%
ex_temp_region1 = (rc.read_temperature(1), 'region1')
ex_temp_region2 = (rc.read_temperature(2), 'region2')
ex_temp_region3 = (rc.read_temperature(3), 'region3')
ex_temp_region4 = (rc.read_temperature(4), 'region4')
ex_temp_region5 = (rc.read_temperature(5), 'region5')
ex_temp_region6 = (rc.read_temperature(6), 'region6')
ex_temp_region7 = (rc.read_temperature(7), 'region7')
ex_temp_region8 = (rc.read_temperature(8), 'region8')

# %%
ac.draw_graph('temperature, degree C', [ex_temp_region1], op='a3')

# %%
ac.draw_graph('temperature, degree C', [ex_temp_region2], op='a3')

# %%
ac.draw_graph('temperature, degree C', [ex_temp_region3], op='a3')

# %%
ac.draw_graph('temperature, degree C', [ex_temp_region4], op='a3')

# %%
ac.draw_graph('temperature, degree C', [ex_temp_region5], op='a3')

# %%
ac.draw_graph('temperature, degree C', [ex_temp_region6], op='a3')

# %%
ac.draw_graph('temperature, degree C', [ex_temp_region7], op='a3')

# %%
ac.draw_graph('temperature, degree C', [ex_temp_region8], op='a3')

# %% [markdown]
# # 外気温度（平均・各地域）

# %%
data = [
    ex_temp_region1,
    ex_temp_region2,
    ex_temp_region3,
    ex_temp_region4,
    ex_temp_region5,
    ex_temp_region6,
    ex_temp_region7,
    ex_temp_region8,
]
ac.draw_graph('daily average temperature, degree C',data, op='ave')

# %% [markdown]
# # 絶対湿度（平均・各地域）

# %%
data = [
    (rc.read_absolute_humidity(1), 'region1'),
    (rc.read_absolute_humidity(2), 'region2'),
    (rc.read_absolute_humidity(3), 'region3'),
    (rc.read_absolute_humidity(4), 'region4'),
    (rc.read_absolute_humidity(5), 'region5'),
    (rc.read_absolute_humidity(6), 'region6'),
    (rc.read_absolute_humidity(7), 'region7'),
    (rc.read_absolute_humidity(8), 'region8'),
]
ac.draw_graph('daily average absolute humidity, kg/kgDA',data, op='ave')

# %% [markdown]
# # 法線面直達日射量

# %% [markdown]
# 日変動が激しすぎるので、地域別に表示

# %%
direct_solar_region1 = (rc.read_direct_solar(1)*3600*10**(-6), 'region1')
direct_solar_region2 = (rc.read_direct_solar(2)*3600*10**(-6), 'region2')
direct_solar_region3 = (rc.read_direct_solar(3)*3600*10**(-6), 'region3')
direct_solar_region4 = (rc.read_direct_solar(4)*3600*10**(-6), 'region4')
direct_solar_region5 = (rc.read_direct_solar(5)*3600*10**(-6), 'region5')
direct_solar_region6 = (rc.read_direct_solar(6)*3600*10**(-6), 'region6')
direct_solar_region7 = (rc.read_direct_solar(7)*3600*10**(-6), 'region7')
direct_solar_region8 = (rc.read_direct_solar(8)*3600*10**(-6), 'region8')

# %% [markdown]
# #### 1 地域

# %%
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',[direct_solar_region1], op='itg')

# %% [markdown]
# #### 2 地域

# %%
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',[direct_solar_region2], op='itg')

# %% [markdown]
# #### 3 地域

# %%
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',[direct_solar_region3], op='itg')

# %% [markdown]
# #### 4 地域

# %%
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',[direct_solar_region4], op='itg')

# %% [markdown]
# #### 5 地域

# %%
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',[direct_solar_region5], op='itg')

# %% [markdown]
# #### 6 地域

# %%
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',[direct_solar_region6], op='itg')

# %% [markdown]
# #### 7 地域

# %%
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',[direct_solar_region7], op='itg')

# %% [markdown]
# #### 8 地域

# %%
ac.draw_graph('daily integrated direct solar radiation, MJ/m2 d',[direct_solar_region8], op='itg')

# %% [markdown]
# # 水平面天空日射量

# %%
data = [
    (rc.read_horizontal_sky_solar(1)*3600*10**(-6), 'region1'),
    (rc.read_horizontal_sky_solar(2)*3600*10**(-6), 'region2'),
    (rc.read_horizontal_sky_solar(3)*3600*10**(-6), 'region3'),
    (rc.read_horizontal_sky_solar(4)*3600*10**(-6), 'region4'),
    (rc.read_horizontal_sky_solar(5)*3600*10**(-6), 'region5'),
    (rc.read_horizontal_sky_solar(6)*3600*10**(-6), 'region6'),
    (rc.read_horizontal_sky_solar(7)*3600*10**(-6), 'region7'),
    (rc.read_horizontal_sky_solar(8)*3600*10**(-6), 'region8'),
]
ac.draw_graph('daily integrated sky solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# # 水平面夜間放射量

# %%
data = [
    (rc.read_night_radiation(1)*3600*10**(-6), 'region1'),
    (rc.read_night_radiation(2)*3600*10**(-6), 'region2'),
    (rc.read_night_radiation(3)*3600*10**(-6), 'region3'),
    (rc.read_night_radiation(4)*3600*10**(-6), 'region4'),
    (rc.read_night_radiation(5)*3600*10**(-6), 'region5'),
    (rc.read_night_radiation(6)*3600*10**(-6), 'region6'),
    (rc.read_night_radiation(7)*3600*10**(-6), 'region7'),
    (rc.read_night_radiation(8)*3600*10**(-6), 'region8')
]
ac.draw_graph('daily integrated night solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# # 水平面日射量

# %%
data = [
    (rc.get_horizontal_solar(1)*3600*10**(-6), 'region1'),
    (rc.get_horizontal_solar(2)*3600*10**(-6), 'region2'),
    (rc.get_horizontal_solar(3)*3600*10**(-6), 'region3'),
    (rc.get_horizontal_solar(4)*3600*10**(-6), 'region4'),
    (rc.get_horizontal_solar(5)*3600*10**(-6), 'region5'),
    (rc.get_horizontal_solar(6)*3600*10**(-6), 'region6'),
    (rc.get_horizontal_solar(7)*3600*10**(-6), 'region7'),
    (rc.get_horizontal_solar(8)*3600*10**(-6), 'region8')
]
ac.draw_graph('daily integrated night solar radiation, MJ/m2 d',data, op='itg')

# %% [markdown]
# # 相当外気温度

# %%
data = [
    (rc.get_sat_temperature(1)*3600*10**(-6), 'region1'),
    (rc.get_sat_temperature(2)*3600*10**(-6), 'region2'),
    (rc.get_sat_temperature(3)*3600*10**(-6), 'region3'),
    (rc.get_sat_temperature(4)*3600*10**(-6), 'region4'),
    (rc.get_sat_temperature(5)*3600*10**(-6), 'region5'),
    (rc.get_sat_temperature(6)*3600*10**(-6), 'region6'),
    (rc.get_sat_temperature(7)*3600*10**(-6), 'region7'),
    (rc.get_sat_temperature(8)*3600*10**(-6), 'region8')
]
ac.draw_graph('daily average SAT temperature, degree C',data, op='ave')
