# %%
import numpy as np

import analyze_control as ac

# %% [markdown]
# # 要求温度

# %% [markdown]
# ## 暖房

# %%
data = [
    (ac.get_requested_supply_air_temperature_for_heating(6)[0], 'room 1 supply'),
    (ac.get_requested_supply_air_temperature_for_heating(6)[1], 'room 2 supply'),
    (ac.get_requested_supply_air_temperature_for_heating(6)[2], 'room 3 supply'),
    (ac.get_requested_supply_air_temperature_for_heating(6)[3], 'room 4 supply'),
    (ac.get_requested_supply_air_temperature_for_heating(6)[4], 'room 5 supply'),
    (ac.get_decided_outlet_supply_air_temperature_for_heating(6), 'total supply'),
]

ac.draw_graph('temperature, degree C', data, op='ave')

# %%
data = [
    (ac.get_requested_supply_air_temperature_for_cooling(6)[0], 'room 1 supply'),
    (ac.get_requested_supply_air_temperature_for_cooling(6)[1], 'room 2 supply'),
    (ac.get_requested_supply_air_temperature_for_cooling(6)[2], 'room 3 supply'),
    (ac.get_requested_supply_air_temperature_for_cooling(6)[3], 'room 4 supply'),
    (ac.get_requested_supply_air_temperature_for_cooling(6)[4], 'room 5 supply'),
    (ac.get_decided_outlet_supply_air_temperature_for_cooling(6), 'total supply'),
]

ac.draw_graph('temperature, degree C', data, op='ave')
