# %%
import numpy as np

import analyze_control as ac

# %% [markdown]
# # 熱源機風量推定のための仮熱負荷

# %% [markdown]
# #### 暖房

# %%
data = [
    (ac.get_main_value(6)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating_MJ/h'], 'standard'),
    (ac.get_main_value(10)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating_MJ/h'], 'small house'),
    (ac.get_main_value(24)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating_MJ/h'], 's55-small'),
    (ac.get_main_value(35)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating_MJ/h'], 'h11more-large'),
]

ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# #### 冷房

# %%
data = [
    (ac.get_main_value(6)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling_MJ/h'], 'standard'),
    (ac.get_main_value(10)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling_MJ/h'], 'small house'),
    (ac.get_main_value(24)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling_MJ/h'], 's55-small'),
    (ac.get_main_value(35)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling_MJ/h'], 'h11more-large'),
]

ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# # 旧負荷(12室)との比較

# %% [markdown]
# この比較に特に意味は無いが、12室負荷計算と、Q値・μ値に基づく推定負荷とのオーダー感が一致しているかを確認する。
# 冷房負荷は全熱負荷で比較。

# %% [markdown]
# #### 暖房

# %% [markdown]
# 標準住宅

# %%
data = [
    (ac.get_main_value(6)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating_MJ/h'], 'estimated'),
    (np.sum(ac.get_heating_load(6), axis=0), 'load(1-12)'),
]

ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# 狭小住宅

# %%
data = [
    (ac.get_main_value(10)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating_MJ/h'], 'estimated'),
    (np.sum(ac.get_heating_load(10), axis=0), 'load(1-12)'),
]

ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# S55 Solar:Small

# %%
data = [
    (ac.get_main_value(24)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating_MJ/h'], 'estimated'),
    (np.sum(ac.get_heating_load(24), axis=0), 'load(1-12)'),
]

ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# h11more Solar:large

# %%
data = [
    (ac.get_main_value(35)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating_MJ/h'], 'estimated'),
    (np.sum(ac.get_heating_load(35), axis=0), 'load(1-12)'),
]

ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# #### 冷房

# %% [markdown]
# 標準住宅

# %%
data = [
    (ac.get_main_value(6)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling_MJ/h'], 'estimated'),
    (np.sum(ac.get_sensible_cooling_load(6), axis=0) + np.sum(ac.get_latent_cooling_load(6), axis=0), 'load(1-12)')
]

ac.draw_graph('cooling load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# 狭小住宅

# %%
data = [
    (ac.get_main_value(10)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling_MJ/h'], 'estimated'),
    (np.sum(ac.get_sensible_cooling_load(10), axis=0) + np.sum(ac.get_latent_cooling_load(10), axis=0), 'load(1-12)')
]

ac.draw_graph('cooling load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# S55 Solar:Small

# %%
data = [
    (ac.get_main_value(24)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling_MJ/h'], 'estimated'),
    (np.sum(ac.get_sensible_cooling_load(24), axis=0) + np.sum(ac.get_latent_cooling_load(24), axis=0), 'load(1-12)')
]

ac.draw_graph('cooling load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# h11more Solar:large

# %%
data = [
    (ac.get_main_value(35)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling_MJ/h'], 'estimated'),
    (np.sum(ac.get_sensible_cooling_load(35), axis=0) + np.sum(ac.get_latent_cooling_load(35), axis=0), 'load(1-12)')
]

ac.draw_graph('cooling load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# # 熱源機風量

# %% [markdown]
# #### 暖房

# %%
data = [
    (ac.get_main_value(6)['time_value']['supply_air_volume_of_heat_source_heating_m3/h'], 'standard'),
    (ac.get_main_value(10)['time_value']['supply_air_volume_of_heat_source_heating_m3/h'], 'small house'),
    (ac.get_main_value(24)['time_value']['supply_air_volume_of_heat_source_heating_m3/h'], 's55-small'),
    (ac.get_main_value(35)['time_value']['supply_air_volume_of_heat_source_heating_m3/h'], 'h11more-large'),
    (ac.get_main_value(49)['time_value']['supply_air_volume_of_heat_source_heating_m3/h'], 'small capacity'),
]

ac.draw_graph('total supply air volume(daily average), m3/h', data, op='ave')

# %% [markdown]
# #### 冷房

# %%
data = [
    (ac.get_main_value(6)['time_value']['supply_air_volume_of_heat_source_cooling_m3/h'], 'standard'),
    (ac.get_main_value(10)['time_value']['supply_air_volume_of_heat_source_cooling_m3/h'], 'small house'),
    (ac.get_main_value(24)['time_value']['supply_air_volume_of_heat_source_cooling_m3/h'], 's55-small'),
    (ac.get_main_value(35)['time_value']['supply_air_volume_of_heat_source_cooling_m3/h'], 'h11more-large'),
    (ac.get_main_value(49)['time_value']['supply_air_volume_of_heat_source_cooling_m3/h'], 'small capacity'),
]

ac.draw_graph('total supply air volume(daily average), m3/h', data, op='ave')

# %% [markdown]
# # 各室の吹き出し風量

# %% [markdown]
# #### 暖房

# %%
data = [
    (ac.get_main_value(6)['time_value']['supply_air_volume_heating_room1_m3/h'], 'room1'),
    (ac.get_main_value(6)['time_value']['supply_air_volume_heating_room2_m3/h'], 'room2'),
    (ac.get_main_value(6)['time_value']['supply_air_volume_heating_room3_m3/h'], 'room3'),
    (ac.get_main_value(6)['time_value']['supply_air_volume_heating_room4_m3/h'], 'room4'),
    (ac.get_main_value(6)['time_value']['supply_air_volume_heating_room5_m3/h'], 'room5'),
]

ac.draw_graph('supply air volume (daily average), m3/h', data, op='ave')

# %% [markdown]
# #### 冷房

# %%
data = [
    (ac.get_main_value(6)['time_value']['supply_air_volume_cooling_room1_m3/h'], 'room1'),
    (ac.get_main_value(6)['time_value']['supply_air_volume_cooling_room2_m3/h'], 'room2'),
    (ac.get_main_value(6)['time_value']['supply_air_volume_cooling_room3_m3/h'], 'room3'),
    (ac.get_main_value(6)['time_value']['supply_air_volume_cooling_room4_m3/h'], 'room4'),
    (ac.get_main_value(6)['time_value']['supply_air_volume_cooling_room5_m3/h'], 'room5'),
]

ac.draw_graph('supply air volume (daily average), m3/h', data, op='ave')
