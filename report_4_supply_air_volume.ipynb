# %%
import numpy as np

import analyze_control as ac

# %% [markdown]
# # 熱源機風量推定のための仮熱負荷

# %% [markdown]
# #### 暖房

# %%
data = [
    (ac.get_main_value(6)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating'], 'standard'),
    (ac.get_main_value(10)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating'], 'small house'),
    (ac.get_main_value(24)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating'], 's55-small'),
    (ac.get_main_value(35)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating'], 'h11more-large'),
]

ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# #### 冷房

# %%
data = [
    (ac.get_main_value(6)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling'], 'standard'),
    (ac.get_main_value(10)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling'], 'small house'),
    (ac.get_main_value(24)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling'], 's55-small'),
    (ac.get_main_value(35)['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling'], 'h11more-large'),
]

ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# # 旧負荷(12室)との比較

# %% [markdown]
# この比較に特に意味は無いが、12室負荷計算と、Q値・μ値に基づく推定負荷とのオーダー感が一致しているかを確認する。
# 冷房負荷は全熱負荷で比較。

# %% [markdown]
# #### 暖房

# %% [markdown]
# 標準住宅

# %%
result = ac.get_main_value(6)
data = [
    (result['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating'], 'estimated'),
    (result['time_value']['old_heating_load_sum_of_12_rooms'], 'load(1-12)'),
]
ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# 狭小住宅

# %%
result = ac.get_main_value(10)
data = [
    (result['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating'], 'estimated'),
    (result['time_value']['old_heating_load_sum_of_12_rooms'], 'load(1-12)'),
]
ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# S55 Solar:Small

# %%
result = ac.get_main_value(24)
data = [
    (result['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating'], 'estimated'),
    (result['time_value']['old_heating_load_sum_of_12_rooms'], 'load(1-12)'),
]
ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# h11more Solar:large

# %%
result = ac.get_main_value(35)
data = [
    (result['time_value']['output_of_heat_source_for_supply_air_volume_estimation_heating'], 'estimated'),
    (result['time_value']['old_heating_load_sum_of_12_rooms'], 'load(1-12)'),
]
ac.draw_graph('heating load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# #### 冷房

# %% [markdown]
# 標準住宅

# %%
result = ac.get_main_value(6)
data = [
    (result['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling'], 'estimated'),
    (result['time_value']['old_sensible_cooling_load_sum_of_12_rooms']
     + result['time_value']['old_latent_cooling_load_sum_of_12_rooms'], 'load(1-12)'),
]
ac.draw_graph('cooling load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# 狭小住宅

# %%
result = ac.get_main_value(10)
data = [
    (result['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling'], 'estimated'),
    (result['time_value']['old_sensible_cooling_load_sum_of_12_rooms']
     + result['time_value']['old_latent_cooling_load_sum_of_12_rooms'], 'load(1-12)'),
]
ac.draw_graph('cooling load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# S55 Solar:Small

# %%
result = ac.get_main_value(24)
data = [
    (result['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling'], 'estimated'),
    (result['time_value']['old_sensible_cooling_load_sum_of_12_rooms']
     + result['time_value']['old_latent_cooling_load_sum_of_12_rooms'], 'load(1-12)'),
]
ac.draw_graph('cooling load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# h11more Solar:large

# %%
result = ac.get_main_value(35)
data = [
    (result['time_value']['output_of_heat_source_for_supply_air_volume_estimation_cooling'], 'estimated'),
    (result['time_value']['old_sensible_cooling_load_sum_of_12_rooms']
     + result['time_value']['old_latent_cooling_load_sum_of_12_rooms'], 'load(1-12)'),
]
ac.draw_graph('cooling load for heat source, MJ/d', data, op='itg')

# %% [markdown]
# # 熱源機風量

# %% [markdown]
# #### 暖房

# %%
data = [
    (ac.get_main_value(6)['time_value']['supply_air_volume_of_heat_source_heating'], 'standard'),
    (ac.get_main_value(10)['time_value']['supply_air_volume_of_heat_source_heating'], 'small house'),
    (ac.get_main_value(24)['time_value']['supply_air_volume_of_heat_source_heating'], 's55-small'),
    (ac.get_main_value(35)['time_value']['supply_air_volume_of_heat_source_heating'], 'h11more-large'),
    (ac.get_main_value(49)['time_value']['supply_air_volume_of_heat_source_heating'], 'small capacity'),
]

ac.draw_graph('total supply air volume(daily average), m3/h', data, op='ave')

# %% [markdown]
# #### 冷房

# %%
data = [
    (ac.get_main_value(6)['time_value']['supply_air_volume_of_heat_source_cooling'], 'standard'),
    (ac.get_main_value(10)['time_value']['supply_air_volume_of_heat_source_cooling'], 'small house'),
    (ac.get_main_value(24)['time_value']['supply_air_volume_of_heat_source_cooling'], 's55-small'),
    (ac.get_main_value(35)['time_value']['supply_air_volume_of_heat_source_cooling'], 'h11more-large'),
    (ac.get_main_value(49)['time_value']['supply_air_volume_of_heat_source_cooling'], 'small capacity'),
]

ac.draw_graph('total supply air volume(daily average), m3/h', data, op='ave')

# %% [markdown]
# # 各室の吹き出し風量

# %%
result = ac.get_main_value(6)

# %% [markdown]
# #### 暖房

# %%
data = [
    (result['time_value']['supply_air_volume_heating_room1'], 'room1'),
    (result['time_value']['supply_air_volume_heating_room2'], 'room2'),
    (result['time_value']['supply_air_volume_heating_room3'], 'room3'),
    (result['time_value']['supply_air_volume_heating_room4'], 'room4'),
    (result['time_value']['supply_air_volume_heating_room5'], 'room5'),
]

ac.draw_graph('supply air volume (daily average), m3/h', data, op='ave')

# %% [markdown]
# #### 冷房

# %%
data = [
    (result['time_value']['supply_air_volume_cooling_room1'], 'room1'),
    (result['time_value']['supply_air_volume_cooling_room2'], 'room2'),
    (result['time_value']['supply_air_volume_cooling_room3'], 'room3'),
    (result['time_value']['supply_air_volume_cooling_room4'], 'room4'),
    (result['time_value']['supply_air_volume_cooling_room5'], 'room5'),
]

ac.draw_graph('supply air volume (daily average), m3/h', data, op='ave')
