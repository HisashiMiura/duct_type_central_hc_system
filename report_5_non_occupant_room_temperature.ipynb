# %%
import numpy as np

import analyze_control as ac

# %% [markdown]
# # 非居室の温度

# %% [markdown]
# #### 暖房

# %%
data = [
    (ac.get_main_value(6)['time_value']['non_occupant_room_temperature_heating_degree_C'], 'standard'),
    (ac.get_main_value(10)['time_value']['non_occupant_room_temperature_heating_degree_C'], 'small house'),
    (ac.get_main_value(24)['time_value']['non_occupant_room_temperature_heating_degree_C'], 's55-small'),
    (ac.get_main_value(35)['time_value']['non_occupant_room_temperature_heating_degree_C'], 'h11more-large'),
]

ac.draw_graph('non occupant room temperature, degree C', data, op='ave')

# %% [markdown]
# #### 冷房

# %%
data = [
    (ac.get_main_value(6)['time_value']['non_occupant_room_temperature_cooling_degree_C'], 'standard'),
    (ac.get_main_value(10)['time_value']['non_occupant_room_temperature_cooling_degree_C'], 'small house'),
    (ac.get_main_value(24)['time_value']['non_occupant_room_temperature_cooling_degree_C'], 's55-small'),
    (ac.get_main_value(35)['time_value']['non_occupant_room_temperature_cooling_degree_C'], 'h11more-large'),
]

ac.draw_graph('non occupant room temperature, degree C', data, op='ave')
